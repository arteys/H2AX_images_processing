# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sns

# %%
path_focii = "C:/Users/Modern/Desktop/Kirill/B8/B8/Images/Counted/MyExpt_H2AX_in_nucleus.csv"
path_nuclei = "C:/Users/Modern/Desktop/Kirill/B8/B8/Images/Counted/MyExpt_Nucleus_filtered.csv"
focii_pd=pd.read_csv(path_focii)
nuclei_pd=pd.read_csv(path_nuclei)
labels_nuclei = nuclei_pd.head()
labels_focii = focii_pd.head()
size = focii_pd.shape[0]
print(labels_nuclei)
# Out:
#    ImageNumber  ObjectNumber  AreaShape_Area  AreaShape_FormFactor  \
# 0            1             1            8665              0.619749
# 1            1             2            6448              0.834499
# 2            1             3            1959              0.840945
# 3            1             4            3080              0.823505
# 4            1             5            3231              0.793470
#
#    Children_Masked_H2AX_Count  Location_Center_X  Location_Center_Y  \
# 0                          54         265.446624         322.168840
# 1                          18         763.563896         355.956731
# 2                          13         272.321593         422.867279
# 3                          23         321.342532         430.879221
# 4                          25         277.588982         479.494893
#
#    Location_Center_Z  Number_Object_Number  Parent_Nucleus
# 0                  0                     1               1
# 1                  0                     2               2
# 2                  0                     3               3
# 3                  0                     4               4
# 4                  0                     5               5

# %%
print(nuclei_pd['Children_Masked_H2AX_Count'])
# Out:
# 0      54
# 1      18
# 2      13
# 3      23
# 4      25
#        ..
# 520    17
# 521    73
# 522    22
# 523    31
# 524    23
# Name: Children_Masked_H2AX_Count, Length: 525, dtype: int64

# %%
ax = sns.histplot(data=nuclei_pd, x =nuclei_pd['Children_Masked_H2AX_Count'])
ax.set(xlabel='Number per nucleus', ylabel='Count')
# Out:
# [Text(0.5, 0, 'Number per nucleus'), Text(0, 0.5, 'Count')]

# %%
ax = sns.scatterplot(data=nuclei_pd, x = nuclei_pd['Children_Masked_H2AX_Count'], y = nuclei_pd['AreaShape_Area'] )
ax.set(xlabel='Number per nucleus', ylabel='Nucleus area')
# Out:
# [Text(0.5, 0, 'Number per nucleus'), Text(0, 0.5, 'Nucleus area')]

# %%
ax = sns.histplot(data=focii_pd, x =focii_pd['Intensity_IntegratedIntensity_Red'])
ax.set(xlabel='Integrated intensity', ylabel='Count')
# Out:
# [Text(0.5, 0, 'Integrated intensity'), Text(0, 0.5, 'Count')]
